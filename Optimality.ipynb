# %%
import numpy as np
import nltk
import requests
import random
import itertools as it
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[165], line 6
#       4 import random
#       5 import itertools as it
# ----> 6 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
languages = ["en_US"]#, "de", "sw", "zh_hans"]

ipas = []
ipa_reverse = {}

print("Starting data fetch...")
for l in languages: 
    print(f"    Fetching language {l}...".ljust(40), end="", flush=True)
    url = f"https://github.com/open-dict-data/ipa-dict/raw/master/data/{l}.txt"
    data = requests.get(url, allow_redirects=True).content.decode('UTF-8')
    len_before = len(ipas)
    pairs = [ p.split("\t") for p in data.split("\n") ]
    for i in range(len(pairs)):
        if len(pairs[i]) == 2:
            word = pairs[i][0]
            
            cleaned = pairs[i][1].replace("ˈ", "").replace("/", "").replace("ˌ", "")
            if "," in cleaned:
                for w in cleaned.split(","):
                    ipas.append(w.strip())
                    ipa_reverse[w.strip()] = f"{l}_{word}"
            else:
                ipas.append(cleaned.strip())
                ipa_reverse[cleaned.strip()] = f"{l}_{word}"
    print(f"Got {(len(ipas) - len_before):,} IPA strings. Total = {len(ipas):,}")
    
print("Done.")
# Out:
# Starting data fetch...
#     Fetching language en_US...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/socket.py:961, in getaddrinfo(host, port, family, type, proto, flags)
#     960 addrlist = []
# --> 961 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     962     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x10ccbb650>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /open-dict-data/ipa-dict/raw/master/data/en_US.txt (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ccbb650>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 10
#       8 print(f"    Fetching language {l}...".ljust(40), end="", flush=True)
#       9 url = f"https://github.com/open-dict-data/ipa-dict/raw/master/data/{l}.txt"
# ---> 10 data = requests.get(url, allow_redirects=True).content.decode('UTF-8')
#      11 len_before = len(ipas)
#      12 pairs = [ p.split("\t") for p in data.split("\n") ]
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Yale/CompLing/PythOT/.venv/lib/python3.11/site-packages/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /open-dict-data/ipa-dict/raw/master/data/en_US.txt (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10ccbb650>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
random.shuffle(ipas)
for i in ipas[:10]:
    print(f"{i}".ljust(20), ipa_reverse[i])

# %%
# =======================
#   GENERATION METHODS
# =======================

devoice_dict = {
    "z" : "s",
    "d" : "t",
    "ʒ" : "ʃ",
    "v" : "f",
    "b" : "p",
    "g" : "k",
    "ð" : "θ",
    "ʤ" : "ʧ"
}

voice_dict = {v: k for (k,v) in  devoice_dict.items()}

def nochange(segment):
    return segment

def devoice(segment):
    if segment in devoice_dict:
        return devoice_dict[segment]
    else:
        return None
    
def voice(segment):
    if segment in voice_dict:
        return voice_dict[segment]
    else:
        return None
    
def omit(segment):
    if (segment == "-"):
        return None
    return ""

def epenthetic_i(segment):
    if (segment == "-"):
        return None
    return segment + "ɨ"

    
generation_methods = (devoice, voice, nochange, omit, epenthetic_i)


# =======================
#   CONSTRAINT METHODS
# =======================


SKIP_CHARS = ['-', '']

def remove_root(s):
    return list(str(s).replace("-", ""))

def voicing_value(c):
    if c in devoice_dict.keys():
        return True
    if c in devoice_dict.values():
        return False
    else:
        return None

def ident_voice(orig, modified):
    violations = 0
    for i, o in zip(orig, modified):
        i_v = voicing_value(i)
        o_v = voicing_value(o)
        
        if (i_v is None) or (o_v is None):
            continue
        
        if i_v != o_v:
            violations += 1
            
    return violations

def ident_voice_root(orig, modified):
    violations = 0
    for i, o in zip(orig, modified):
        if i == "-":
            break
        i_v = voicing_value(i)
        o_v = voicing_value(o)
        
        if (i_v is None) or (o_v is None):
            continue
        
        if i_v != o_v:
            violations += 1
            
    return violations

def dont_delete(orig, modified):
    violations = 0
    for i, o in zip(orig, modified):
        if i != "" and o == "":
            violations += 1
    return violations

def dont_epenthesize(orig, modified):
    violations = 0
    for i, o in zip(orig, modified):
        if len(o) > len(i):
            violations += 1
    return violations


def voicing_agreement(_, modified):
    violations = 0
    modified = list(filter(lambda x: x not in SKIP_CHARS, ''.join(modified)))
    
    for i in range(len(modified)-1):
        a = modified[i]
        b = modified[i+1]
        
        v1 = voicing_value(a)
        v2 = voicing_value(b)
        
        if (v1 is None) or (v2 is None):
            continue
        
        if v1 != v2:
            violations += 1
            
    return violations


sibilants = "szʃʧʒʤ"

def no_SS(original, modified):
    violations = 0
    modified = list(filter(lambda x: x not in SKIP_CHARS, ''.join(modified)))
    
    for i in range(len(modified)-1):
        a = modified[i]
        b = modified[i+1]
        
        if ((a in sibilants) and (b in sibilants)):
            violations+=1
            
    return violations
                    

constraints = (no_SS, voicing_agreement, dont_delete, dont_epenthesize, ident_voice_root, ident_voice,)
constraint_names = ("VAG", "*SS", "MAX", "DEP", "IVR", "IDV")

# %%
def gen(input_ipa):
    original = list(input_ipa)
    N = len(generation_methods)
    K = len(original)
    
    possibilities = set(it.combinations(generation_methods * K, K))
    
    output = []
    
    for p in possibilities:
        out = []
        for orig_char, transform in zip(original, p):
            out.append(transform(orig_char))
        if None not in out:
            output.append(out)    
    return output

# %%
original = "glas-z"
print(f"Generating possibilities for {''.join(original)}:")

ranked = []

for s in sorted(gen(original)):
    violations = []
    for c in constraints:
        violations.append(c(original, s))
    ranked.append([s, violations])
    
print(f"Constraint ranking: {'.'.join(constraint_names)}")
for (s,v) in sorted(ranked, key=lambda x: x[1]):
    print(f"'{''.join(s).replace('-', '')}'\t\t{ ' '.join(list(s[0] + ':' + str(s[1]) for s in list(zip(constraint_names, v))))}")
# Out:
# Generating possibilities for glas-z:
# Constraint ranking: VAG.*SS.MAX.DEP.IVR.IDV
# 'glasɨz'		VAG:0 *SS:0 MAX:0 DEP:1 IVR:0 IDV:0
# 'glasɨs'		VAG:0 *SS:0 MAX:0 DEP:1 IVR:0 IDV:1
# 'klasɨz'		VAG:0 *SS:0 MAX:0 DEP:1 IVR:1 IDV:1
# 'klasɨs'		VAG:0 *SS:0 MAX:0 DEP:1 IVR:1 IDV:2
# 'glasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:0
# 'glaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:0
# 'glɨasɨz'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:0
# 'gɨlasɨz'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:0
# 'glaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'glɨasɨs'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'gɨlasɨs'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'klasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'klaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'klɨasɨz'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'klaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:1 IDV:2
# 'klɨasɨs'		VAG:0 *SS:0 MAX:0 DEP:2 IVR:1 IDV:2
# 'glaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'glɨasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'glɨaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlɨasɨz'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:0
# 'glɨaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:1
# 'gɨlaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:1
# 'gɨlɨasɨs'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:0 IDV:1
# 'klaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'klɨasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'klɨaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'klɨaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:3 IVR:1 IDV:2
# 'glɨaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:0 IDV:0
# 'gɨlaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:0 IDV:0
# 'gɨlɨasɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:0 IDV:0
# 'gɨlɨaɨsɨz'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:0 IDV:0
# 'gɨlɨaɨsɨs'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:0 IDV:1
# 'klɨaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:4 IVR:1 IDV:1
# 'gɨlɨaɨsɨzɨ'		VAG:0 *SS:0 MAX:0 DEP:5 IVR:0 IDV:0
# 'glaz'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:0 IDV:0
# 'glas'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:0 IDV:0
# 'glas'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:0 IDV:1
# 'glaz'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'klaz'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'klas'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'klas'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:1 IDV:2
# 'klaz'		VAG:0 *SS:0 MAX:1 DEP:0 IVR:2 IDV:2
# 'lasɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'gasɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glsɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glazɨ'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glasɨ'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glaɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glaɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glɨaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'glɨas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'gɨlaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'gɨlas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:0
# 'lasɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'gasɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'glsɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'glaɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'glɨas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'gɨlas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'glaɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'glɨaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'gɨlaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'kasɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klsɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klazɨ'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klasɨ'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klaɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klaɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klɨaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'klɨas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'kasɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'klsɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'klaɨs'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'klɨas'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'klaɨz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'klɨaz'		VAG:0 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'lasɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'laɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'lɨasɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gasɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gaɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨazɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨasɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨasɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlazɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlasɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlɨaz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlɨas'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:0
# 'laɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'lɨasɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gaɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'glɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'glɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨasɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨlsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨlaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨlɨas'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'glɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨlaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨlɨaz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'kasɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'kaɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨazɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨasɨ'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'kaɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:2
# 'klɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:2
# 'klɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:1 IDV:2
# 'klɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:2 IVR:2 IDV:2
# 'laɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'lɨasɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'lɨaɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gaɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'glɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'glɨaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'glɨaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨasɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨaɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨsɨz'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨazɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨasɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:0
# 'lɨaɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:1
# 'gɨaɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:1
# 'gɨlɨsɨs'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:1
# 'gɨlɨaɨs'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:0 IDV:1
# 'gɨlɨaɨz'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'kaɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'klɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'klɨaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'klɨaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'lɨaɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:4 IVR:0 IDV:0
# 'gɨaɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:4 IVR:0 IDV:0
# 'gɨlɨsɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:4 IVR:0 IDV:0
# 'gɨlɨaɨzɨ'		VAG:0 *SS:0 MAX:1 DEP:4 IVR:0 IDV:0
# 'gɨlɨaɨsɨ'		VAG:0 *SS:0 MAX:1 DEP:4 IVR:0 IDV:0
# 'laz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'las'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'gaz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'gas'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'glz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'gls'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'gla'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:0
# 'las'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:1
# 'gas'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:1
# 'gls'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:0 IDV:1
# 'laz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'gaz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'glz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kaz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kas'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'klz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kls'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kla'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kas'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:2
# 'kls'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:1 IDV:2
# 'kaz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:2 IDV:2
# 'klz'		VAG:0 *SS:0 MAX:2 DEP:0 IVR:2 IDV:2
# 'asɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'lsɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'lazɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'lasɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'laɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'laɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'lɨaz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'lɨas'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gazɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gasɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gaɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gaɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glzɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glsɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glaɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'glɨa'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨaz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨas'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨlz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨls'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨla'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:0
# 'asɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'lsɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'laɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'lɨas'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'gaɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'glɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'gɨas'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'gɨls'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'laɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'lɨaz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'gaɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'glɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'gɨaz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'gɨlz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'ksɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'kazɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'kasɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'kaɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'kaɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klzɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klsɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klaɨ'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'klɨa'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'ksɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:2
# 'kaɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:2
# 'klɨs'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:1 IDV:2
# 'kaɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:2 IDV:2
# 'klɨz'		VAG:0 *SS:0 MAX:2 DEP:1 IVR:2 IDV:2
# 'asɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'aɨsɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lsɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'laɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'laɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨsɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨazɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨasɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨaɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨaɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gaɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gaɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'glɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'glɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'glɨaɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨsɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨazɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨasɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨaɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨaɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlaɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨlɨa'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:0
# 'aɨsɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'lɨsɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'lɨaɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'gɨsɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'gɨaɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'gɨlɨs'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:0 IDV:1
# 'lɨaɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'gɨaɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'gɨlɨz'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'ksɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'kaɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'kaɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'klɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'klɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'klɨaɨ'		VAG:0 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'aɨsɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'lɨsɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'lɨaɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'lɨaɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨsɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨaɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨaɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨlɨzɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨlɨsɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'gɨlɨaɨ'		VAG:0 *SS:0 MAX:2 DEP:3 IVR:0 IDV:0
# 'az'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'as'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'lz'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'ls'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'la'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'gz'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'ga'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'gl'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:0
# 'as'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:1
# 'ls'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:0 IDV:1
# 'az'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'lz'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'gz'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'ks'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'ka'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'kl'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'ks'		VAG:0 *SS:0 MAX:3 DEP:0 IVR:1 IDV:2
# 'sɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'azɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'asɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'aɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'aɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'lzɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'lsɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'laɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'lɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'lɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'lɨa'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gzɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gaɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'glɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gɨa'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'gɨl'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:0
# 'sɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:1
# 'aɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:1
# 'lɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:1
# 'gɨs'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:0 IDV:1
# 'aɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'lɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'gɨz'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'ksɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'kaɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'klɨ'		VAG:0 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'sɨzɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'aɨzɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'aɨsɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'lɨzɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'lɨsɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'lɨaɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'gɨzɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'gɨsɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'gɨaɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'gɨlɨ'		VAG:0 *SS:0 MAX:3 DEP:2 IVR:0 IDV:0
# 'z'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:0
# 's'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:0
# 'a'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:0
# 'l'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:0
# 'g'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:0
# 's'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:0 IDV:1
# 'z'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:1 IDV:1
# 'k'		VAG:0 *SS:0 MAX:4 DEP:0 IVR:1 IDV:1
# 'zɨ'		VAG:0 *SS:0 MAX:4 DEP:1 IVR:0 IDV:0
# 'sɨ'		VAG:0 *SS:0 MAX:4 DEP:1 IVR:0 IDV:0
# 'aɨ'		VAG:0 *SS:0 MAX:4 DEP:1 IVR:0 IDV:0
# 'lɨ'		VAG:0 *SS:0 MAX:4 DEP:1 IVR:0 IDV:0
# 'gɨ'		VAG:0 *SS:0 MAX:4 DEP:1 IVR:0 IDV:0
# ''		VAG:0 *SS:0 MAX:5 DEP:0 IVR:0 IDV:0
# 'gsɨz'		VAG:0 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'gsɨs'		VAG:0 *SS:1 MAX:2 DEP:1 IVR:0 IDV:1
# 'gsɨzɨ'		VAG:0 *SS:1 MAX:2 DEP:2 IVR:0 IDV:0
# 'gs'		VAG:0 *SS:1 MAX:3 DEP:0 IVR:0 IDV:0
# 'gs'		VAG:0 *SS:1 MAX:3 DEP:0 IVR:0 IDV:1
# 'kz'		VAG:0 *SS:1 MAX:3 DEP:0 IVR:1 IDV:1
# 'kz'		VAG:0 *SS:1 MAX:3 DEP:0 IVR:2 IDV:2
# 'gsɨ'		VAG:0 *SS:1 MAX:3 DEP:1 IVR:0 IDV:0
# 'kzɨ'		VAG:0 *SS:1 MAX:3 DEP:1 IVR:1 IDV:1
# 'glass'		VAG:1 *SS:0 MAX:0 DEP:0 IVR:0 IDV:1
# 'glazz'		VAG:1 *SS:0 MAX:0 DEP:0 IVR:1 IDV:1
# 'klass'		VAG:1 *SS:0 MAX:0 DEP:0 IVR:1 IDV:2
# 'klazz'		VAG:1 *SS:0 MAX:0 DEP:0 IVR:2 IDV:2
# 'glaɨss'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:0 IDV:1
# 'glɨass'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:0 IDV:1
# 'gɨlass'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:0 IDV:1
# 'glazzɨ'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:1
# 'glaɨzz'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:1
# 'glɨazz'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:1
# 'gɨlazz'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:1
# 'klaɨss'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:2
# 'klɨass'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:1 IDV:2
# 'klazzɨ'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:2 IDV:2
# 'klaɨzz'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:2 IDV:2
# 'klɨazz'		VAG:1 *SS:0 MAX:0 DEP:1 IVR:2 IDV:2
# 'glɨaɨss'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'gɨlaɨss'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'gɨlɨass'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:0 IDV:1
# 'glaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'glɨazzɨ'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'glɨaɨzz'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'gɨlazzɨ'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'gɨlaɨzz'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'gɨlɨazz'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:1
# 'klɨaɨss'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:1 IDV:2
# 'klaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:2 IDV:2
# 'klɨazzɨ'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:2 IDV:2
# 'klɨaɨzz'		VAG:1 *SS:0 MAX:0 DEP:2 IVR:2 IDV:2
# 'gɨlɨaɨss'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:0 IDV:1
# 'glɨaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'gɨlaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'gɨlɨazzɨ'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'gɨlɨaɨzz'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:1 IDV:1
# 'klɨaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:3 IVR:2 IDV:2
# 'gɨlɨaɨzzɨ'		VAG:1 *SS:0 MAX:0 DEP:4 IVR:1 IDV:1
# 'lass'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:0 IDV:1
# 'gass'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:0 IDV:1
# 'glss'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:0 IDV:1
# 'lazz'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'gazz'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'glzz'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:1 IDV:1
# 'kass'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:1 IDV:2
# 'klss'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:1 IDV:2
# 'kazz'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:2 IDV:2
# 'klzz'		VAG:1 *SS:0 MAX:1 DEP:0 IVR:2 IDV:2
# 'laɨss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'lɨass'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'gaɨss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'glɨss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'gɨass'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'gɨlss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:0 IDV:1
# 'lazzɨ'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'laɨzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'lɨazz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'gazzɨ'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'gaɨzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'glzzɨ'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'glɨzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'gɨazz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'gɨlzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:1
# 'kaɨss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'klɨss'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:1 IDV:2
# 'kazzɨ'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'kaɨzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'klzzɨ'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'klɨzz'		VAG:1 *SS:0 MAX:1 DEP:1 IVR:2 IDV:2
# 'lɨaɨss'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨaɨss'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'gɨlɨss'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:0 IDV:1
# 'laɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'lɨazzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'lɨaɨzz'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gaɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'glɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨazzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨaɨzz'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨlzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'gɨlɨzz'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:1 IDV:1
# 'kaɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:2 IDV:2
# 'klɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:2 IVR:2 IDV:2
# 'lɨaɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'gɨaɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'gɨlɨzzɨ'		VAG:1 *SS:0 MAX:1 DEP:3 IVR:1 IDV:1
# 'ass'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:0 IDV:1
# 'lss'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:0 IDV:1
# 'azz'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'lzz'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'gzz'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:1 IDV:1
# 'kss'		VAG:1 *SS:0 MAX:2 DEP:0 IVR:1 IDV:2
# 'aɨss'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'lɨss'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'gɨss'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:0 IDV:1
# 'azzɨ'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'aɨzz'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'lzzɨ'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'lɨzz'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'gzzɨ'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'gɨzz'		VAG:1 *SS:0 MAX:2 DEP:1 IVR:1 IDV:1
# 'aɨzzɨ'		VAG:1 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'lɨzzɨ'		VAG:1 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'gɨzzɨ'		VAG:1 *SS:0 MAX:2 DEP:2 IVR:1 IDV:1
# 'ss'		VAG:1 *SS:0 MAX:3 DEP:0 IVR:0 IDV:1
# 'zz'		VAG:1 *SS:0 MAX:3 DEP:0 IVR:1 IDV:1
# 'zzɨ'		VAG:1 *SS:0 MAX:3 DEP:1 IVR:1 IDV:1
# 'glasz'		VAG:1 *SS:1 MAX:0 DEP:0 IVR:0 IDV:0
# 'klasz'		VAG:1 *SS:1 MAX:0 DEP:0 IVR:1 IDV:1
# 'glazs'		VAG:1 *SS:1 MAX:0 DEP:0 IVR:1 IDV:2
# 'klazs'		VAG:1 *SS:1 MAX:0 DEP:0 IVR:2 IDV:3
# 'glaszɨ'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:0 IDV:0
# 'glaɨsz'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:0 IDV:0
# 'glɨasz'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:0 IDV:0
# 'gɨlasz'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:0 IDV:0
# 'klaszɨ'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:1
# 'klaɨsz'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:1
# 'klɨasz'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:1
# 'glaɨzs'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:2
# 'glɨazs'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:2
# 'gɨlazs'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:1 IDV:2
# 'klaɨzs'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:2 IDV:3
# 'klɨazs'		VAG:1 *SS:1 MAX:0 DEP:1 IVR:2 IDV:3
# 'glaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'glɨaszɨ'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'glɨaɨsz'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'gɨlaszɨ'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'gɨlaɨsz'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'gɨlɨasz'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:0 IDV:0
# 'klaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:1
# 'klɨaszɨ'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:1
# 'klɨaɨsz'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:1
# 'glɨaɨzs'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:2
# 'gɨlaɨzs'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:2
# 'gɨlɨazs'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:1 IDV:2
# 'klɨaɨzs'		VAG:1 *SS:1 MAX:0 DEP:2 IVR:2 IDV:3
# 'glɨaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlɨaszɨ'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:0 IDV:0
# 'gɨlɨaɨsz'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:0 IDV:0
# 'klɨaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:1 IDV:1
# 'gɨlɨaɨzs'		VAG:1 *SS:1 MAX:0 DEP:3 IVR:1 IDV:2
# 'gɨlɨaɨszɨ'		VAG:1 *SS:1 MAX:0 DEP:4 IVR:0 IDV:0
# 'lasz'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:0 IDV:0
# 'gasz'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:0 IDV:0
# 'glsz'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:0 IDV:0
# 'kasz'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:1 IDV:1
# 'klsz'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:1 IDV:1
# 'lazs'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:1 IDV:2
# 'gazs'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:1 IDV:2
# 'glzs'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:1 IDV:2
# 'kazs'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:2 IDV:3
# 'klzs'		VAG:1 *SS:1 MAX:1 DEP:0 IVR:2 IDV:3
# 'laszɨ'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'laɨsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'lɨasz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'gaszɨ'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'gaɨsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'glszɨ'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'glɨsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'gɨasz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'gɨlsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:0 IDV:0
# 'kaszɨ'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:1
# 'kaɨsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:1
# 'klszɨ'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:1
# 'klɨsz'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:1
# 'laɨzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'lɨazs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'gaɨzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'glɨzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'gɨazs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'gɨlzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:1 IDV:2
# 'kaɨzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:2 IDV:3
# 'klɨzs'		VAG:1 *SS:1 MAX:1 DEP:1 IVR:2 IDV:3
# 'laɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'lɨaszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'lɨaɨsz'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'gaɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'glɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨaszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨaɨsz'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'gɨlɨsz'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:0 IDV:0
# 'kaɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:1 IDV:1
# 'klɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:1 IDV:1
# 'lɨaɨzs'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:1 IDV:2
# 'gɨaɨzs'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:1 IDV:2
# 'gɨlɨzs'		VAG:1 *SS:1 MAX:1 DEP:2 IVR:1 IDV:2
# 'lɨaɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨaɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:3 IVR:0 IDV:0
# 'gɨlɨszɨ'		VAG:1 *SS:1 MAX:1 DEP:3 IVR:0 IDV:0
# 'asz'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:0 IDV:0
# 'lsz'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:0 IDV:0
# 'gss'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:0 IDV:1
# 'ksz'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:1 IDV:1
# 'azs'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:1 IDV:2
# 'lzs'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:1 IDV:2
# 'gzs'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:1 IDV:2
# 'kzz'		VAG:1 *SS:1 MAX:2 DEP:0 IVR:2 IDV:2
# 'aszɨ'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'aɨsz'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'lszɨ'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'lɨsz'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'gɨsz'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:0 IDV:0
# 'kszɨ'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:1 IDV:1
# 'aɨzs'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:1 IDV:2
# 'lɨzs'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:1 IDV:2
# 'gɨzs'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:1 IDV:2
# 'kzzɨ'		VAG:1 *SS:1 MAX:2 DEP:1 IVR:2 IDV:2
# 'aɨszɨ'		VAG:1 *SS:1 MAX:2 DEP:2 IVR:0 IDV:0
# 'lɨszɨ'		VAG:1 *SS:1 MAX:2 DEP:2 IVR:0 IDV:0
# 'gɨszɨ'		VAG:1 *SS:1 MAX:2 DEP:2 IVR:0 IDV:0
# 'sz'		VAG:1 *SS:1 MAX:3 DEP:0 IVR:0 IDV:0
# 'zs'		VAG:1 *SS:1 MAX:3 DEP:0 IVR:1 IDV:2
# 'szɨ'		VAG:1 *SS:1 MAX:3 DEP:1 IVR:0 IDV:0
# 'gsz'		VAG:1 *SS:2 MAX:2 DEP:0 IVR:0 IDV:0
# 'kzs'		VAG:1 *SS:2 MAX:2 DEP:0 IVR:2 IDV:3
# 'gszɨ'		VAG:1 *SS:2 MAX:2 DEP:1 IVR:0 IDV:0

# %%
no_SS("", ['g','l', 'a', '', '-', 's'])
# Out:
# 1

# %%
"" in sibilants
# Out:
# True

# %%
generation_methods[1]("M")
# Out:
# 'MI'

# %%
generation_methods
# Out:
# [<function __main__.nochange(segment)>,
#  <function __main__.<lambda>(segment)>,
#  <function __main__.<lambda>(segment)>]
